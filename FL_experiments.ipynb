# %%
# Cuda config
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import tensorflow as tf
print(f"Num GPUs Available: {len(tf.config.experimental.list_physical_devices('GPU'))}\nLogical: {len(tf.config.experimental.list_logical_devices('GPU'))}")
# Out:
# Num GPUs Available: 1
# Logical: 1

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
import random

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_paths, mask_paths, labels, batch_size=32, is_segmentation=True, input_size=(256, 256), num_classes=4, shuffle=True):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.labels = labels
        self.batch_size = batch_size
        self.is_segmentation = is_segmentation
        self.input_size = input_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return len(self.image_paths) // self.batch_size

    def __getitem__(self, index):
        batch_image_paths = self.image_paths[index * self.batch_size:(index + 1) * self.batch_size]
        batch_mask_paths = self.mask_paths[index * self.batch_size:(index + 1) * self.batch_size]
        batch_labels = self.labels[index * self.batch_size:(index + 1) * self.batch_size]
        
        images, masks, labels = self.__data_generation(batch_image_paths, batch_mask_paths, batch_labels)
        return [images, masks], labels

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.image_paths))
            np.random.shuffle(indices)
            self.image_paths = [self.image_paths[i] for i in indices]
            self.mask_paths = [self.mask_paths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

    def __data_generation(self, batch_image_paths, batch_mask_paths, batch_labels):
        images = np.empty((self.batch_size, *self.input_size, 1))
        masks = np.empty((self.batch_size, *self.input_size, 1))
        labels = np.empty((self.batch_size), dtype=int)

        for i, (image_path, mask_path, label) in enumerate(zip(batch_image_paths, batch_mask_paths, batch_labels)):
            image = load_img(image_path, color_mode='grayscale', target_size=self.input_size)
            mask = load_img(mask_path, color_mode='grayscale', target_size=self.input_size)

            image = img_to_array(image) / 255.0
            mask = img_to_array(mask) / 255.0

            images[i,] = image
            masks[i,] = mask
            labels[i] = label

        return images, masks, labels

# %% [markdown]
# # Baseline Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Multiply, Add, Activation
from tensorflow.keras.models import Model

def attention_module(inputs):
    avg_pool = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    max_pool = tf.keras.layers.GlobalMaxPooling2D()(inputs)

    avg_dense = Dense(inputs.shape[-1] // 8, activation='relu')(avg_pool)
    avg_dense = Dense(inputs.shape[-1], activation='sigmoid')(avg_dense)

    max_dense = Dense(inputs.shape[-1] // 8, activation='relu')(max_pool)
    max_dense = Dense(inputs.shape[-1], activation='sigmoid')(max_dense)

    channel_attention = Add()([avg_dense, max_dense])
    channel_attention = Activation('sigmoid')(channel_attention)

    channel_attention = Multiply()([inputs, channel_attention])
    return channel_attention

def create_cnn_with_attention(input_shape=(256, 256, 1), num_classes=4):
    im_input = Input(shape=input_shape)
    mask_input = Input(shape=input_shape)
    classification_input = tf.keras.layers.Multiply()([im_input, mask_input])

    x = Conv2D(32, kernel_size=(3, 3), activation='relu')(classification_input)
    x = Conv2D(32, kernel_size=(3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = attention_module(x)

    x = Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = attention_module(x)

    x = Conv2D(128, kernel_size=(3, 3), activation='relu')(x)
    x = Conv2D(128, kernel_size=(3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = attention_module(x)

    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    class_output = Dense(num_classes, activation='softmax', name='class_output')(x)

    model = Model(inputs=[im_input, mask_input], outputs=class_output)
    model.compile(optimizer='adam', 
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy')
    return model

model = create_cnn_with_attention()
model.summary()
# Out:
# Model: "model_1502"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3005 (InputLayer)         [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# input_3006 (InputLayer)         [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# multiply_6008 (Multiply)        (None, 256, 256, 1)  0           input_3005[0][0]
#                                                                  input_3006[0][0]
# __________________________________________________________________________________________________
# conv2d_9012 (Conv2D)            (None, 254, 254, 32) 320         multiply_6008[0][0]
# __________________________________________________________________________________________________
# conv2d_9013 (Conv2D)            (None, 252, 252, 32) 9248        conv2d_9012[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4506 (MaxPooling2 (None, 126, 126, 32) 0           conv2d_9013[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4506 ( (None, 32)           0           max_pooling2d_4506[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4506 (Glob (None, 32)           0           max_pooling2d_4506[0][0]
# __________________________________________________________________________________________________
# dense_19526 (Dense)             (None, 4)            132         global_average_pooling2d_4506[0][
# __________________________________________________________________________________________________
# dense_19528 (Dense)             (None, 4)            132         global_max_pooling2d_4506[0][0]
# __________________________________________________________________________________________________
# dense_19527 (Dense)             (None, 32)           160         dense_19526[0][0]
# __________________________________________________________________________________________________
# dense_19529 (Dense)             (None, 32)           160         dense_19528[0][0]
# __________________________________________________________________________________________________
# add_4506 (Add)                  (None, 32)           0           dense_19527[0][0]
#                                                                  dense_19529[0][0]
# __________________________________________________________________________________________________
# activation_4506 (Activation)    (None, 32)           0           add_4506[0][0]
# __________________________________________________________________________________________________
# multiply_6009 (Multiply)        (None, 126, 126, 32) 0           max_pooling2d_4506[0][0]
#                                                                  activation_4506[0][0]
# __________________________________________________________________________________________________
# conv2d_9014 (Conv2D)            (None, 124, 124, 64) 18496       multiply_6009[0][0]
# __________________________________________________________________________________________________
# conv2d_9015 (Conv2D)            (None, 122, 122, 64) 36928       conv2d_9014[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4507 (MaxPooling2 (None, 61, 61, 64)   0           conv2d_9015[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4507 ( (None, 64)           0           max_pooling2d_4507[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4507 (Glob (None, 64)           0           max_pooling2d_4507[0][0]
# __________________________________________________________________________________________________
# dense_19530 (Dense)             (None, 8)            520         global_average_pooling2d_4507[0][
# __________________________________________________________________________________________________
# dense_19532 (Dense)             (None, 8)            520         global_max_pooling2d_4507[0][0]
# __________________________________________________________________________________________________
# dense_19531 (Dense)             (None, 64)           576         dense_19530[0][0]
# __________________________________________________________________________________________________
# dense_19533 (Dense)             (None, 64)           576         dense_19532[0][0]
# __________________________________________________________________________________________________
# add_4507 (Add)                  (None, 64)           0           dense_19531[0][0]
#                                                                  dense_19533[0][0]
# __________________________________________________________________________________________________
# activation_4507 (Activation)    (None, 64)           0           add_4507[0][0]
# __________________________________________________________________________________________________
# multiply_6010 (Multiply)        (None, 61, 61, 64)   0           max_pooling2d_4507[0][0]
#                                                                  activation_4507[0][0]
# __________________________________________________________________________________________________
# conv2d_9016 (Conv2D)            (None, 59, 59, 128)  73856       multiply_6010[0][0]
# __________________________________________________________________________________________________
# conv2d_9017 (Conv2D)            (None, 57, 57, 128)  147584      conv2d_9016[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4508 (MaxPooling2 (None, 28, 28, 128)  0           conv2d_9017[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4508 ( (None, 128)          0           max_pooling2d_4508[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4508 (Glob (None, 128)          0           max_pooling2d_4508[0][0]
# __________________________________________________________________________________________________
# dense_19534 (Dense)             (None, 16)           2064        global_average_pooling2d_4508[0][
# __________________________________________________________________________________________________
# dense_19536 (Dense)             (None, 16)           2064        global_max_pooling2d_4508[0][0]
# __________________________________________________________________________________________________
# dense_19535 (Dense)             (None, 128)          2176        dense_19534[0][0]
# __________________________________________________________________________________________________
# dense_19537 (Dense)             (None, 128)          2176        dense_19536[0][0]
# __________________________________________________________________________________________________
# add_4508 (Add)                  (None, 128)          0           dense_19535[0][0]
#                                                                  dense_19537[0][0]
# __________________________________________________________________________________________________
# activation_4508 (Activation)    (None, 128)          0           add_4508[0][0]
# __________________________________________________________________________________________________
# multiply_6011 (Multiply)        (None, 28, 28, 128)  0           max_pooling2d_4508[0][0]
#                                                                  activation_4508[0][0]
# __________________________________________________________________________________________________
# flatten_1502 (Flatten)          (None, 100352)       0           multiply_6011[0][0]
# __________________________________________________________________________________________________
# dense_19538 (Dense)             (None, 128)          12845184    flatten_1502[0][0]
# __________________________________________________________________________________________________
# class_output (Dense)            (None, 4)            516         dense_19538[0][0]
# ==================================================================================================
# Total params: 13,143,388
# Trainable params: 13,143,388
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Client logic

# %%
def client_update(model, data_generator, epochs=1, byzantine=False, attack_type=None):
    if not byzantine:
        model.fit(data_generator, epochs=epochs, verbose=1)
        return model.get_weights()
    
    if attack_type == 'random_update':
        return [np.random.randn(*w.shape) for w in model.get_weights()]
    
    elif attack_type == 'scaling_attack':
        scale_factor = 100
        model.fit(data_generator, epochs=epochs, verbose=0)
        return [w * scale_factor for w in model.get_weights()]
    
    elif attack_type == 'sign_flipping':
        model.fit(data_generator, epochs=epochs, verbose=0)
        return [-w for w in model.get_weights()]
    
    elif attack_type == 'targeted_attack':
        model.fit(data_generator, epochs=epochs, verbose=0)
        targeted_weights = model.get_weights()
        for layer in targeted_weights:
            layer += np.random.normal(0, 1, size=layer.shape)
        return targeted_weights

# %% [markdown]
# ### MultiKrum logic

# %%
from sklearn.metrics.pairwise import euclidean_distances
def multi_krum(updates, num_to_select, f):
    distances = euclidean_distances([np.concatenate([u.flatten() for u in update]) for update in updates])

    scores = []
    for i in range(len(updates)):
        sorted_distances = np.sort(distances[i])
        scores.append(np.sum(sorted_distances[:len(updates) - f - 1]))
    
    selected_indices = np.argsort(scores)[:num_to_select]
    print(f"Selected clients: {selected_indices}")
    return selected_indices

def apply_weights(model, weights):
    model.set_weights(weights)

# %% [markdown]
# ### FoolsGold logic

# %%
def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    return dot_product / (norm1 * norm2)

def compute_similarity(grad1, grad2):
    dot_product = np.dot(grad1.flatten(), grad2.flatten())
    norm1 = np.linalg.norm(grad1)
    norm2 = np.linalg.norm(grad2)
    return dot_product / (norm1 * norm2)

def fools_gold_weighting(client_gradients):
    num_clients = len(client_gradients)
    sim_matrix = np.zeros((num_clients, num_clients))

    for i in range(num_clients):
        for j in range(i + 1, num_clients):
            sim = cosine_similarity(client_gradients[i][0], client_gradients[j][0])
            sim_matrix[i, j] = sim_matrix[j, i] = sim

    client_weights = np.ones(num_clients)

    for i in range(num_clients):
        max_sim = np.max(sim_matrix[i, :])
        client_weights[i] = 1 - max_sim

    client_weights = np.clip(client_weights, 0, 1)
    print(f"Weights assigned to the chosen clients: {client_weights}")
    return client_weights

def apply_fools_gold_weights(updates, client_weights):
    weighted_updates = [ [layer * client_weights[i] for layer in updates[i]] for i in range(len(updates)) ]
    return np.sum(weighted_updates, axis=0) / np.sum(client_weights)

# %% [markdown]
# # Data prep

# %%
DATA_PATH = "path_to_dataset_dir/COVID-19_Radiography_Dataset"
label_map = {
'COVID': 0,
'Lung_Opacity': 1,
'Normal': 2,
'Viral Pneumonia': 3
}
image_paths = []
mask_paths = []
labels = []
for label_name, label_index in label_map.items():
    images_dir = os.path.join(DATA_PATH, label_name, 'images')
    masks_dir = os.path.join(DATA_PATH, label_name, 'masks')
    image_files = os.listdir(images_dir)

    for image_file in image_files:
        image_path = os.path.join(images_dir, image_file)
        mask_path = os.path.join(masks_dir, image_file)

        image_paths.append(image_path)
        mask_paths.append(mask_path)
        labels.append(label_index)

for label_name, label_index in label_map.items():
    images_dir = os.path.join(DATA_PATH, label_name, 'images')
    masks_dir = os.path.join(DATA_PATH, label_name, 'masks')
    image_files = os.listdir(images_dir)
    
    for image_file in image_files:
        image_path = os.path.join(images_dir, image_file)
        mask_path = os.path.join(masks_dir, image_file)

        image_paths.append(image_path)
        mask_paths.append(mask_path)
        labels.append(label_index)

image_paths_train, image_paths_test, mask_paths_train, mask_paths_test, labels_train, labels_test = train_test_split(
    image_paths, mask_paths, labels, test_size=0.1, random_state=42)

# %%
import math
from scipy.stats import binom
def determine_k(N, f, delta=0.75, tolerance=0.05):
    expected_malicious = f / N

    for k in range(math.ceil(N / 2), N + 1):
        expected_malicious_in_k = k * expected_malicious
        
        probability_bound = np.exp(-delta**2 * expected_malicious_in_k / 3)
        
        if probability_bound <= tolerance:
            return k
    
    return N

# %%
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %% [markdown]
# # FL training scenarios

# %%
def federated_simulation_with_fools_gold(image_paths, mask_paths, labels, num_clients=5, num_rounds=10, f=1, attack_type='random_update'):
    model = create_cnn_with_attention()

    image_splits = np.array_split(image_paths, num_clients)
    mask_splits = np.array_split(mask_paths, num_clients)
    labels_splits = np.array_split(labels, num_clients)

    local_generators = []
    for client_id in range(num_clients):
        generator = DataGenerator(image_splits[client_id], mask_splits[client_id], labels_splits[client_id], batch_size=32, is_segmentation=True)
        local_generators.append(generator)

    byzantine_clients = random.sample(range(num_clients), f)

    delta = 0.75
    tolerance = 0.1
    f_est = num_clients//3
    m = determine_k(num_clients, f_est, delta, tolerance)
    print(f"NUMER OF SELECTED CLIENTS: {m}")

    global_model_performance = []
    byzantine_detected_rounds = []
    all_client_gradients = [[] for _ in range(num_clients)]

    for round_num in range(num_rounds):
        print(f"Round {round_num+1}/{num_rounds}")

        updates = []
        client_gradients = []
        for client_id, generator in enumerate(local_generators):
            local_model = create_cnn_with_attention()
            local_model.set_weights(model.get_weights())

            byzantine = client_id in byzantine_clients
            if byzantine:
                print(f"Client {client_id} is Byzantine")
            client_weights = client_update(local_model, generator, byzantine=byzantine, epochs=1, attack_type=attack_type)
            updates.append(client_weights)

            flattened_weights = np.concatenate([layer.flatten() for layer in client_weights])
            client_gradients.append(flattened_weights)

        selected_updates = multi_krum(updates, num_to_select=m, f=f)

        for i, grad in enumerate(client_gradients):
            all_client_gradients[i].append(grad)

        fg_weights = fools_gold_weighting([all_client_gradients[i] for i in selected_updates])
        aggregated_weights = apply_fools_gold_weights([updates[i] for i in selected_updates], fg_weights)
        apply_weights(model, aggregated_weights)
        print("Global model eval:")
        model.evaluate(DataGenerator(image_paths_test, mask_paths_test, labels_test, batch_size=32, is_segmentation=True, shuffle=False))
    return model, global_model_performance, byzantine_detected_rounds

num_clients = 60
num_rounds = 25
f = 20
attack_type = 'targeted_attack'

global_model, global_model_performance, byzantine_detected_rounds = federated_simulation_with_fools_gold(image_paths_train, mask_paths_train, labels_train, 
                                                                                     num_clients=num_clients, num_rounds=num_rounds, 
                                                                                     f=f, attack_type=attack_type)
# Out:
# NUMER OF SELECTED CLIENTS: 37
# Round 1/25
# 19/19 [==============================] - 3s 87ms/step - loss: 1.2804 - accuracy: 0.4605
# 19/19 [==============================] - 2s 86ms/step - loss: 1.3944 - accuracy: 0.4194
# Client 2 is Byzantine
# 19/19 [==============================] - 2s 87ms/step - loss: 1.2334 - accuracy: 0.4194
# 19/19 [==============================] - 2s 87ms/step - loss: 1.3201 - accuracy: 0.4408
# Client 5 is Byzantine
# 19/19 [==============================] - 3s 90ms/step - loss: 1.3779 - accuracy: 0.4539
# 19/19 [==============================] - 2s 88ms/step - loss: 1.1883 - accuracy: 0.4901
# Client 8 is Byzantine
# 19/19 [==============================] - 2s 86ms/step - loss: 1.2827 - accuracy: 0.4309
# 19/19 [==============================] - 2s 87ms/step - loss: 1.2680 - accuracy: 0.4523
# Client 11 is Byzantine
# 19/19 [==============================] - 2s 87ms/step - loss: 1.1855 - accuracy: 0.4457
# 19/19 [==============================] - 2s 88ms/step - loss: 1.1499 - accuracy: 0.5214
# 19/19 [==============================] - 2s 88ms/step - loss: 1.2319 - accuracy: 0.4868
# Client 15 is Byzantine
# Client 16 is Byzantine
# 19/19 [==============================] - 2s 88ms/step - loss: 1.2234 - accuracy: 0.4720
# 19/19 [==============================] - 2s 88ms/step - loss: 1.2157 - accuracy: 0.4655
# 19/19 [==============================] - 2s 88ms/step - loss: 1.2738 - accuracy: 0.4243
# 19/19 [==============================] - 2s 88ms/step - loss: 1.1829 - accuracy: 0.4868
# 19/19 [==============================] - 2s 89ms/step - loss: 1.3282 - accuracy: 0.4309
# 19/19 [==============================] - 3s 91ms/step - loss: 1.2447 - accuracy: 0.4770
# Client 23 is Byzantine
# Client 24 is Byzantine
# 19/19 [==============================] - 2s 89ms/step - loss: 1.2526 - accuracy: 0.4359
# Client 26 is Byzantine
# 19/19 [==============================] - 2s 89ms/step - loss:
is Byzantine
# 19/19 [==============================] - 3s 91ms/step - loss: 0.7504 - accuracy: 0.7007
# 19/19 [==============================] - 3s 91ms/step - loss: 0.6741 - accuracy: 0.7188
# Client 8 is Byzantine
# 19/19 [==============================] - 2s 88ms/step - loss: 0.7828 - accuracy: 0.6891
# 19/19 [==============================] - 2s 88ms/step - loss: 0.7332 - accuracy: 0.7105
# Client 11 is Byzantine
# 19/19 [==============================] - 2s 89ms/step - loss: 0.7957 - accuracy: 0.7171
# 19/19 [==============================] - 2s 88ms/step - loss: 0.7146 - accuracy: 0.7220
# 19/19 [==============================] - 2s 87ms/step - loss: 0.7145 - accuracy: 0.7303
# Client 15 is Byzantine
# Client 16 is Byzantine
# ...
# 19/19 [==============================] - 3s 94ms/step - loss: 0.6670 - accuracy: 0.7270
# Client 43 is Byzantine
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6192 - accuracy: 0.7434
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6738 - accuracy: 0.7204
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6924 - accuracy: 0.7401
# Client 47 is Byzantine
# Client 48 is Byzantine
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6868 - accuracy: 0.7303
# Client 50 is Byzantine
# 19/19 [==============================] - 3s 92ms/step - loss: 0.5873 - accuracy: 0.7648
# 19/19 [==============================] - 3s 91ms/step - loss: 0.5916 - accuracy: 0.7812
# Client 53 is Byzantine
# 19/19 [==============================] - 2s 89ms/step - loss: 0.6154 - accuracy: 0.7648
# 19/19 [==============================] - 4s 96ms/step - loss: 0.6413 - accuracy: 0.7401
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6484 - accuracy: 0.7451
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6297 - accuracy: 0.7599
# Client 58 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6237 - accuracy: 0.7566
# Selected clients: [57 25 54 52 19 34 13 20 22 46 36 21 55 12 51 44 14 59  4  3 42 35 28  7
#   1 41 31  9 56  6 17 18 49 45 38 27 37]
# Weights assigned to the chosen clients: [0.09137785 0.09347087 0.0897091  0.08386183 0.08663464 0.08931351
#  0.0967837  0.08193535 0.08668894 0.08992666 0.08773524 0.08862323
#  0.09023041 0.09903532 0.08759099 0.08416378 0.09183735 0.08416378
#  0.09493828 0.09941936 0.08421743 0.09621543 0.0778271  0.08769435
#  0.08836681 0.08099169 0.08845347 0.08168828 0.08006471 0.08804625
#  0.08183372 0.08620197 0.09168863 0.09120452 0.0778271  0.08168828
#  0.09079403]
# Global model eval:
# 132/132 [==============================] - 13s 100ms/step - loss: 0.5816 - accuracy: 0.7711
# Round 23/25
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6286 - accuracy: 0.7336
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6579 - accuracy: 0.7664
# Client 2 is Byzantine
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6080 - accuracy: 0.7895
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6478 - accuracy: 0.7319
# Client 5 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6466 - accuracy: 0.7352
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6051 - accuracy: 0.7845
# Client 8 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6294 - accuracy: 0.7500
# Selected clients: [12 46 18 59  3 44  6 19 10 22 55 17 57 28  7 54 13 25  1 52 29 14 38  0
#  41 42 49 37  9 51 56 20 36  4 31 34 35]
# Weights assigned to the chosen clients: [0.09903532 0.08992666 0.08620197 0.08416378 0.09941936 0.08416378
#  0.09079403 0.08663464 0.09579748 0.08668894 0.09023041 0.08183372
#  0.09203798 0.0778271  0.08769435 0.0897091  0.0967837  0.09347087
#  0.08836681 0.08386183 0.07939023 0.09183735 0.0778271  0.08615416
#  0.08099169 0.08421743 0.07939023 0.09079403 0.0878154  0.08759099
#  0.08006471 0.08193535 0.08773524 0.09493828 0.08845347 0.08931351
#  0.09621543]
# Global model eval:
# 132/132 [==============================] - 13s 100ms/step - loss: 0.5733 - accuracy: 0.7730
# Round 24/25
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6117 - accuracy: 0.7434
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6256 - accuracy: 0.7714
# Client 2 is Byzantine
# 19/19 [==============================] - 3s 95ms/step - loss: 0.5947 - accuracy: 0.7895
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6145 - accuracy: 0.7681
# Client 5 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6169 - accuracy: 0.7434
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6422 - accuracy: 0.7549
# Client 8 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6246 - accuracy: 0.7418
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6708 - accuracy: 0.7434
# Client 11 is Byzantine
# 19/19 [==============================] - 3s 93ms/step - loss: 0.5967 - accuracy: 0.7928
# 19/19 [==============================] - 3s 92ms/step - loss: 0.5962 - accuracy: 0.7780
# 19/19 [==============================] - 4s 103ms/step - loss: 0.5892 - accuracy: 0.7812
# Client 15 is Byzantine
# Client 16 is Byzantine
# 19/19 [==============================] - 3s 101ms/step - loss: 0.6979 - accuracy: 0.7434
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6490 - accuracy: 0.7615
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6269 - accuracy: 0.7500
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6817 - accuracy: 0.7352
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6681 - accuracy: 0.7418
# 19/19 [==============================] - 3s 100ms/step - loss: 0.5779 - accuracy: 0.7928
# Client 23 is Byzantine
# Client 24 is Byzantine
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6267 - accuracy: 0.7599
# Client 26 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.5715 - accuracy: 0.7944
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6194 - accuracy: 0.7615
# 19/19 [==============================] - 3s 97ms/step - loss: 0.5530 - accuracy: 0.8059
# Client 30 is Byzantine
# 19/19 [==============================] - 3s 94ms/step - loss: 0.6615 - accuracy: 0.7434
# Client 32 is Byzantine
# Client 33 is Byzantine
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6680 - accuracy: 0.7451
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6259 - accuracy: 0.7697
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6230 - accuracy: 0.7648
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6670 - accuracy: 0.7418
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6285 - accuracy: 0.7780
# Client 39 is Byzantine
# Client 40 is Byzantine
# 19/19 [==============================] - 4s 102ms/step - loss: 0.5862 - accuracy: 0.7632
# 19/19 [==============================] - 3s 103ms/step - loss: 0.6266 - accuracy: 0.7632
# Client 43 is Byzantine
# 19/19 [==============================] - 3s 102ms/step - loss: 0.6715 - accuracy: 0.7648
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6626 - accuracy: 0.7500
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6586 - accuracy: 0.7664
# Client 47 is Byzantine
# Client 48 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6472 - accuracy: 0.7664
# Client 50 is Byzantine
# 19/19 [==============================] - 3s 97ms/step - loss: 0.5716 - accuracy: 0.7697
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6277 - accuracy: 0.7599
# Client 53 is Byzantine
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6328 - accuracy: 0.7467
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6274 - accuracy: 0.7632
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6559 - accuracy: 0.7648
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6073 - accuracy: 0.7582
# Client 58 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.7033 - accuracy: 0.7533
# Selected clients: [54 28  1 27  4 44 10 29 38 52 45 51 36 14 31  3 13 37 18 21 22  9 56 57
#  55 25 34 19 12 42 35 59  7 17 49  0 46]
# Weights assigned to the chosen clients: [0.09418297 0.0778271  0.08836681 0.08168828 0.09493828 0.08416378
#  0.09209639 0.07939023 0.0778271  0.08386183 0.09260368 0.09558064
#  0.08773524 0.09271795 0.08884478 0.09941936 0.0967837  0.0910179
#  0.0912869  0.08500564 0.0892058  0.08168828 0.08006471 0.09137785
#  0.09023041 0.09347087 0.09154767 0.08663464 0.09903532 0.08421743
#  0.09789038 0.08416378 0.0912869  0.08876735 0.07939023 0.08382231
#  0.08992666]
# Global model eval:
# 132/132 [==============================] - 13s 94ms/step - loss: 0.5670 - accuracy: 0.7768
# Round 25/25
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6965 - accuracy: 0.7072
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6349 - accuracy: 0.7533
# Client 2 is Byzantine
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6367 - accuracy: 0.7566
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6176 - accuracy: 0.7796
# Client 5 is Byzantine
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6472 - accuracy: 0.7401
# 19/19 [==============================] - 3s 91ms/step - loss: 0.6085 - accuracy: 0.7812
# Client 8 is Byzantine
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6572 - accuracy: 0.7516
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6273 - accuracy: 0.7648
# Client 11 is Byzantine
# 19/19 [==============================] - 3s 99ms/step - loss: 0.5818 - accuracy: 0.7796
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6180 - accuracy: 0.7796
# 19/19 [==============================] - 3s 99ms/step - loss: 0.5980 - accuracy: 0.7928
# Client 15 is Byzantine
# Client 16 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6933 - accuracy: 0.7319
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6381 - accuracy: 0.7845
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6263 - accuracy: 0.7533
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6686 - accuracy: 0.7467
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6537 - accuracy: 0.7516
# 19/19 [==============================] - 3s 96ms/step - loss: 0.5568 - accuracy: 0.7928
# Client 23 is Byzantine
# Client 24 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6275 - accuracy: 0.7533
# Client 26 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6090 - accuracy: 0.7862
# 19/19 [==============================] - 3s 95ms/step - loss: 0.5920 - accuracy: 0.7615
# 19/19 [==============================] - 3s 92ms/step - loss: 0.5534 - accuracy: 0.7747
# Client 30 is Byzantine
# 19/19 [==============================] - 3s 93ms/step - loss: 0.6874 - accuracy: 0.7451
# Client 32 is Byzantine
# Client 33 is Byzantine
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6554 - accuracy: 0.7599
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6093 - accuracy: 0.7632
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6014 - accuracy: 0.7664
# 19/19 [==============================] - 3s 99ms/step - loss: 0.6248 - accuracy: 0.7500
# 19/19 [==============================] - 3s 102ms/step - loss: 0.5783 - accuracy: 0.7763
# Client 39 is Byzantine
# Client 40 is Byzantine
# 19/19 [==============================] - 3s 101ms/step - loss: 0.5983 - accuracy: 0.7648
# 19/19 [==============================] - 3s 101ms/step - loss: 0.6785 - accuracy: 0.7336
# Client 43 is Byzantine
# 19/19 [==============================] - 3s 99ms/step - loss: 0.5931 - accuracy: 0.7730
# 19/19 [==============================] - 3s 97ms/step - loss: 0.6523 - accuracy: 0.7286
# 19/19 [==============================] - 3s 100ms/step - loss: 0.6517 - accuracy: 0.7484
# Client 47 is Byzantine
# Client 48 is Byzantine
# 19/19 [==============================] - 3s 98ms/step - loss: 0.6481 - accuracy: 0.7352
# Client 50 is Byzantine
# 19/19 [==============================] - 3s 96ms/step - loss: 0.5725 - accuracy: 0.7812
# 19/19 [==============================] - 3s 96ms/step - loss: 0.6265 - accuracy: 0.7632
# Client 53 is Byzantine
# 19/19 [==============================] - 3s 94ms/step - loss: 0.6218 - accuracy: 0.7582
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6257 - accuracy: 0.7648
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6922 - accuracy: 0.7385
# 19/19 [==============================] - 3s 95ms/step - loss: 0.6040 - accuracy: 0.7697
# Client 58 is Byzantine
# 19/19 [==============================] - 3s 92ms/step - loss: 0.6389 - accuracy: 0.7385
# Selected clients: [18  1 46 54 36 38 13 12 41  7 31 42 57 52 10 19 27 22 14 56 21  4 37 28
#  45 20 25  6  3 29 59  0 44 17 35 51 34]
# Weights assigned to the chosen clients: [0.08620197 0.08836681 0.0907436  0.0897091  0.08773524 0.0778271
#  0.0967837  0.09903532 0.08099169 0.08769435 0.08845347 0.08421743
#  0.09137785 0.08386183 0.09209639 0.08663464 0.08382231 0.08668894
#  0.09183735 0.08006471 0.08500564 0.0951187  0.09079403 0.0778271
#  0.09120452 0.08193535 0.09347087 0.08804625 0.09941936 0.08507234
#  0.08416378 0.08382231 0.08416378 0.08183372 0.09621543 0.08759099
#  0.08931351]
# Global model eval:
# 132/132 [==============================] - 13s 93ms/step - loss: 0.5604 - accuracy: 0.7815
